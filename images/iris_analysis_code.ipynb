# %%
import pandas as pd

# %%
Iris=pd.read_csv("/content/IRIS.csv",
na_values=["NA","-","?","Null"],
encoding='latin-1',
    on_bad_lines='skip')

# %%
Iris.head(12)

# %%
Iris.shape

# %%
Iris.info()

# %%
Iris.describe()

# %%
Iris.columns.tolist()

# %%
Iris.isnull().sum()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
 
# Step 4: Scatter Plot
# Relationship between features
 

plt.figure(figsize=(8, 5))
sns.scatterplot(
    data=Iris,
    x='sepal_length',
    y='petal_length',
    hue='species',
    palette='Set1',
    s=80
)
plt.title("Sepal Length vs Petal Length by Species")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Petal Length (cm)")
plt.legend(title="Species")
plt.tight_layout()
plt.show()

# %%
 
# Step 5: Histograms
# Value distributions of each feature
 

df.drop('species', axis=1).hist(
    bins=20,
    figsize=(10, 6),
    color='steelblue',
    edgecolor='black'
)
plt.suptitle("Feature Distributions — Iris Dataset", fontsize=14)
plt.tight_layout()
plt.show()

# %%
 
# Step 6: Box Plots
# Outlier detection per feature per species
  

fig, axes = plt.subplots(2, 2, figsize=(12, 8))
features = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

for i, ax in enumerate(axes.flatten()):
    sns.boxplot(
        data=df,
        x='species',
        y=features[i],
        palette='Set2',
        ax=ax
    )
    ax.set_title(f"{features[i]} by Species")
    ax.set_xlabel("Species")

plt.suptitle("Box Plots — Outlier Detection", fontsize=14)
plt.tight_layout()
plt.show()

# %%
 
# Step 7: Key Insights & Conclusions
 

print("""

1. DATASET OVERVIEW:
   - 150 rows, 5 columns (4 features + 1 target)
   - 3 species: setosa, versicolor, virginica
   - No missing values — clean dataset

2. SCATTER PLOT FINDINGS:
   - Iris-setosa is clearly separable from others
   - Petal length is the most discriminative feature
   - Versicolor and Virginica slightly overlap

3. HISTOGRAM FINDINGS:
   - Petal features show bimodal distribution
   - Setosa has very small petals (peak near 1-2cm)
   - Sepal width is normally distributed

4. BOX PLOT FINDINGS:
   - Outliers found in sepal_width and petal_width
   - Virginica has largest petal dimensions
   - Setosa is most compact and consistent

5. CONCLUSION:
   - Petal length and petal width are best features
     for classifying Iris species
   - This dataset is ideal for classification models
""")
